# %% [markdown]
# #            Exploratory data analysis (EDA) on SMART PHONES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('./smartphones.csv')

# %%
df.head()
# Out:
#   brand_name                      model  price  rating  has_5g  has_nfc  \
# 0    oneplus              OnePlus 11 5G  54999    89.0    True     True
# 1    oneplus  OnePlus Nord CE 2 Lite 5G  19989    81.0    True    False
# 2    samsung      Samsung Galaxy A14 5G  16499    75.0    True    False
# 3   motorola       Motorola Moto G62 5G  14999    81.0    True    False
# 4     realme         Realme 10 Pro Plus  24999    82.0    True    False
#
#    has_ir_blaster processor_brand  num_cores  processor_speed  ...  \
# 0           False      snapdragon        8.0              3.2  ...
# 1           False      snapdragon        8.0              2.2  ...
# 2           False          exynos        8.0              2.4  ...
# 3           False      snapdragon        8.0              2.2  ...
# 4           False       dimensity        8.0              2.6  ...
#
#    refresh_rate  num_rear_cameras  num_front_cameras       os  \
# 0           120                 3                1.0  android
# ...

# %%
df.columns
# Out:
# Index(['brand_name', 'model', 'price', 'rating', 'has_5g', 'has_nfc',
#        'has_ir_blaster', 'processor_brand', 'num_cores', 'processor_speed',
#        'battery_capacity', 'fast_charging_available', 'fast_charging',
#        'ram_capacity', 'internal_memory', 'screen_size', 'refresh_rate',
#        'num_rear_cameras', 'num_front_cameras', 'os', 'primary_camera_rear',
#        'primary_camera_front', 'extended_memory_available', 'extended_upto',
#        'resolution_width', 'resolution_height'],
#       dtype='object')

# %%
df.shape
# Out:
# (980, 26)

# %%
df.isna().sum()
# Out:
# brand_name                     0
# model                          0
# price                          0
# rating                       101
# has_5g                         0
# has_nfc                        0
# has_ir_blaster                 0
# processor_brand               20
# num_cores                      6
# processor_speed               42
# battery_capacity              11
# fast_charging_available        0
# fast_charging                211
# ram_capacity                   0
# internal_memory                0
# screen_size                    0
# refresh_rate                   0
# num_rear_cameras               0
# num_front_cameras              4
# os                            14
# primary_camera_rear            0
# primary_camera_front           5
# extended_memory_available      0
# extended_upto                480
# resolution_width               0
# resolution_height              0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 980 entries, 0 to 979
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 980 non-null    object
#  1   model                      980 non-null    object
#  2   price                      980 non-null    int64
#  3   rating                     879 non-null    float64
#  4   has_5g                     980 non-null    bool
#  5   has_nfc                    980 non-null    bool
#  6   has_ir_blaster             980 non-null    bool
#  7   processor_brand            960 non-null    object
#  8   num_cores                  974 non-null    float64
#  9   processor_speed            938 non-null    float64
#  10  battery_capacity           969 non-null    float64
#  11  fast_charging_available    980 non-null    int64
#  12  fast_charging              769 non-null    float64
# ...

# %%
df.describe()
# Out:
#                price      rating   num_cores  processor_speed  \
# count     980.000000  879.000000  974.000000       938.000000
# mean    32520.504082   78.258248    7.772074         2.427217
# std     39531.812669    7.402854    0.836845         0.464090
# min      3499.000000   60.000000    4.000000         1.200000
# 25%     12999.000000   74.000000    8.000000         2.050000
# 50%     19994.500000   80.000000    8.000000         2.300000
# 75%     35491.500000   84.000000    8.000000         2.840000
# max    650000.000000   89.000000    8.000000         3.220000
#
#        battery_capacity  fast_charging_available  fast_charging  ram_capacity  \
# count        969.000000               980.000000     769.000000    980.000000
# mean        4817.748194                 0.854082      46.126138      6.560204
# std         1009.540054                 0.353205      34.277870      2.744378
# min         1821.000000                 0.000000      10.000000      1.000000
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
null_cols=[]
df.columns
for i in df.columns:
    if any(df[i].isna()):
        null_cols.append(i)

# %%
null_cols
# Out:
# ['rating',
#  'processor_brand',
#  'num_cores',
#  'processor_speed',
#  'battery_capacity',
#  'fast_charging',
#  'num_front_cameras',
#  'os',
#  'primary_camera_front',
#  'extended_upto']

# %%
df[null_cols].head()
# Out:
#    rating processor_brand  num_cores  processor_speed  battery_capacity  \
# 0    89.0      snapdragon        8.0              3.2            5000.0
# 1    81.0      snapdragon        8.0              2.2            5000.0
# 2    75.0          exynos        8.0              2.4            5000.0
# 3    81.0      snapdragon        8.0              2.2            5000.0
# 4    82.0       dimensity        8.0              2.6            5000.0
#
#    fast_charging  num_front_cameras       os  primary_camera_front  \
# 0          100.0                1.0  android                  16.0
# 1           33.0                1.0  android                  16.0
# 2           15.0                1.0  android                  13.0
# 3            NaN                1.0  android                  16.0
# 4           67.0                1.0  android                  16.0
#
#    extended_upto
# 0            NaN
# 1         1024.0
# 2         1024.0
# 3         1024.0
# 4            NaN

# %%
df_missing=df[null_cols]

# %%
df_missing.describe().style.background_gradient(cmap='Oranges')
# Out:
# <style type="text/css">
# #T_d55cd_row0_col0, #T_d55cd_row0_col1, #T_d55cd_row0_col2, #T_d55cd_row0_col4, #T_d55cd_row0_col5, #T_d55cd_row0_col6, #T_d55cd_row7_col3, #T_d55cd_row7_col7 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_d55cd_row0_col3, #T_d55cd_row1_col2, #T_d55cd_row1_col5, #T_d55cd_row2_col0, #T_d55cd_row2_col1, #T_d55cd_row2_col2, #T_d55cd_row2_col3, #T_d55cd_row2_col5, #T_d55cd_row3_col1, #T_d55cd_row3_col2, #T_d55cd_row3_col4, #T_d55cd_row3_col5, #T_d55cd_row3_col6, #T_d55cd_row3_col7, #T_d55cd_row4_col2, #T_d55cd_row4_col5, #T_d55cd_row5_col2, #T_d55cd_row5_col5, #T_d55cd_row6_col2, #T_d55cd_row6_col5, #T_d55cd_row7_col2, #T_d55cd_row7_col5 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_d55cd_row0_col7 {
#   background-color: #fdd3a9;
#   color: #000000;
# }
# #T_d55cd_row1_col0 {
#   background-color: #feecd9;
#   color: #000000;
# }
# ...

# %%
mean_rating=df['rating'].mean()
df['rating'].fillna(mean_rating,inplace=True)

# %%
df['rating'].isna().sum()
# Out:
# 0

# %%
df['fast_charging'].unique()
# Out:
# array([100.,  33.,  15.,  nan,  67.,  25., 120.,  80.,  18.,  45.,  10.,
#         66.,  44., 210.,  30., 150.,  68.,  50.,  20.,  65., 180., 125.,
#         40.,  60., 200., 240.,  19.,  21., 135., 165.,  22.,  27.,  55.])

# %%
df['fast_charging'].describe()
# Out:
# count    769.000000
# mean      46.126138
# std       34.277870
# min       10.000000
# 25%       18.000000
# 50%       33.000000
# 75%       66.000000
# max      240.000000
# Name: fast_charging, dtype: float64

# %%
charging_values=[20,25,40,55,65]
random_values=np.random.choice(charging_values,df['fast_charging'].isna().sum(),replace=True)
random_values
# Out:
# array([65, 25, 40, 20, 25, 20, 20, 20, 40, 55, 55, 40, 65, 55, 55, 65, 25,
#        20, 20, 25, 25, 55, 65, 40, 40, 20, 65, 25, 55, 40, 40, 25, 40, 20,
#        40, 65, 65, 65, 25, 65, 65, 25, 65, 25, 20, 40, 20, 65, 65, 40, 25,
#        65, 20, 55, 25, 65, 55, 25, 55, 65, 40, 55, 40, 55, 40, 55, 40, 25,
#        20, 65, 65, 55, 25, 65, 55, 65, 20, 40, 20, 65, 40, 40, 20, 20, 55,
#        40, 25, 55, 40, 40, 20, 25, 40, 40, 25, 20, 65, 40, 55, 40, 25, 65,
#        20, 55, 65, 65, 20, 25, 55, 20, 25, 65, 25, 40, 40, 55, 55, 40, 55,
#        40, 20, 65, 20, 55, 40, 40, 25, 55, 65, 25, 25, 55, 65, 65, 20, 25,
#        25, 25, 40, 20, 25, 40, 40, 65, 40, 40, 40, 25, 25, 55, 40, 20, 20,
#        25, 25, 65, 65, 25, 25, 55, 65, 40, 25, 25, 25, 25, 65, 20, 55, 65,
#        20, 55, 55, 20, 40, 25, 55, 20, 20, 40, 55, 20, 65, 65, 40, 25, 65,
#        65, 25, 25, 65, 55, 55, 65, 65, 40, 65, 55, 20, 40, 55, 65, 55, 25,
#        25, 55, 25, 55, 20, 25, 25])

# %%
df.loc[df['fast_charging'].isna(),'fast_charging']=random_values

# %%
df['fast_charging'].isna().sum()
# Out:
# 0

# %%
df['extended_upto'].fillna(df['extended_upto'].mean(),inplace=True)
df['battery_capacity'].fillna(df['battery_capacity'].mean(),inplace=True)
df['processor_speed'].fillna(df['processor_speed'].mean(),inplace=True)

# %%
df.isna().sum()
# Out:
# brand_name                    0
# model                         0
# price                         0
# rating                        0
# has_5g                        0
# has_nfc                       0
# has_ir_blaster                0
# processor_brand              20
# num_cores                     6
# processor_speed               0
# battery_capacity              0
# fast_charging_available       0
# fast_charging                 0
# ram_capacity                  0
# internal_memory               0
# screen_size                   0
# refresh_rate                  0
# num_rear_cameras              0
# num_front_cameras             4
# os                           14
# primary_camera_rear           0
# primary_camera_front          5
# extended_memory_available     0
# extended_upto                 0
# resolution_width              0
# resolution_height             0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (937, 26)

# %%
df.describe().T.style.background_gradient(cmap='plasma')
# Out:
# <style type="text/css">
# ...

# %%
num_cols=df.select_dtypes(include=['int64','float64']).columns

# %%
num_cols
# Out:
# Index(['price', 'rating', 'num_cores', 'processor_speed', 'battery_capacity',
#        'fast_charging_available', 'fast_charging', 'ram_capacity',
#        'internal_memory', 'screen_size', 'refresh_rate', 'num_rear_cameras',
#        'num_front_cameras', 'primary_camera_rear', 'primary_camera_front',
#        'extended_memory_available', 'extended_upto', 'resolution_width',
#        'resolution_height'],
#       dtype='object')

# %%
fig,axis=plt.subplots(7,3,figsize=(20,35))
axis=axis.flatten()
for i,col in enumerate(num_cols):
    sns.histplot(data=df,x=col,kde=True,color='blue',ax=axis[i])
    title = col.replace('_', ' ').title()  
    axis[i].set_title(title)


plt.tight_layout()
plt.show()

# %%
os_counts=df['os'].value_counts()
subplot_color = 'white'
fast_charging_counts = df['fast_charging_available'].value_counts()
fig, axes = plt.subplots(2, 2, figsize=(10, 8), facecolor=subplot_color)
sns.countplot(data=df, x='os', ax=axes[0, 0])
axes[0, 0].set_xlabel('OS')
axes[0, 0].set_ylabel('Count')
axes[0, 0].set_facecolor(subplot_color)


axes[0, 1].pie(os_counts.values, labels=os_counts.index, autopct='%1.2f%%')
axes[0, 1].set_facecolor(subplot_color)

axes[0, 0].set_title('Distribution of Operating Systems')
axes[0, 1].set_title('Distribution of Operating Systems')

sns.countplot(data=df, x='fast_charging_available', ax=axes[1, 0])
axes[1, 0].set_xlabel('Fast Charging Available')
axes[1, 0].set_ylabel('Count')
axes[1, 0].set_facecolor(subplot_color)


axes[1, 1].pie(fast_charging_counts.values, labels=fast_charging_counts.index, autopct='%1.2f%%')
axes[1, 1].set_facecolor(subplot_color)

axes[1, 0].set_title('Distribution of Fast Charging Availability')
axes[1, 1].set_title('Distribution of Fast Charging Availability')

plt.tight_layout()

plt.show()

# %%
brands=df['brand_name'].value_counts()
brands_index=brands.index
plt.figure(figsize=(14,6))
sns.countplot(data=df,x='brand_name',order=brands_index)
plt.xticks(rotation=90)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 937 entries, 0 to 978
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand_name                 937 non-null    object
#  1   model                      937 non-null    object
#  2   price                      937 non-null    int64
#  3   rating                     937 non-null    float64
#  4   has_5g                     937 non-null    bool
#  5   has_nfc                    937 non-null    bool
#  6   has_ir_blaster             937 non-null    bool
#  7   processor_brand            937 non-null    object
#  8   num_cores                  937 non-null    float64
#  9   processor_speed            937 non-null    float64
#  10  battery_capacity           937 non-null    float64
#  11  fast_charging_available    937 non-null    int64
#  12  fast_charging              937 non-null    float64
# ...

# %%
bool_cols=['has_5g','has_nfc','has_ir_blaster']
plt.figure(figsize=(16,10))

for i,feature in enumerate(bool_cols,1):
    counts=df[feature].value_counts()
    plt.subplot(2, 3, i)
    plt.pie(counts, labels=counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.tab10.colors)
    plt.title(f'{feature.capitalize()} Distribution')
    plt.axis('equal')
    
plt.tight_layout()
plt.show()

# %%
numeric_cols = df.select_dtypes(include=['int64', 'float64'])
corr_matrix = numeric_cols.corr()
plt.figure(figsize=(20, 12))
sns.heatmap(corr_matrix, annot=True, cmap='tab20c', fmt=".2f", vmin = -1, vmax = 1)
plt.title('CORRELATION HEAT MAP OF MOBILE FEATURES')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df['num_front_cameras'],y=df['num_rear_cameras'])
plt.title('Font cameras vs Back cameras')
plt.xlabel('Font cameras')
plt.ylabel('Back cameras')
plt.show()

# %%
sorted_df=df.sort_values(by='brand_name',ascending=True)
plt.figure(figsize=(6,4))
sns.barplot(data=sorted_df,x='brand_name',y='rating')
plt.title('BRAND VS RATING')
plt.xlabel('Brand')
plt.ylabel('Rating')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.barplot(data=sorted_df,x='brand_name',y='price')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.barplot(data=sorted_df,x='processor_brand',y='price')
plt.title("Processor brand vs Price")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.barplot(data=sorted_df,x='processor_brand',y='refresh_rate',palette='Set3')
plt.xticks(rotation=60)
plt.title("Processor_brand vs Refresh_rate")
plt.show()

# %%
plt.figure(figsize=(10, 4))
sns.barplot(data=df, x='brand_name', y='ram_capacity', palette='viridis')
plt.xlabel('Brand Name')
plt.ylabel('RAM Capacity')
plt.title('Brand Name vs RAM Capacity')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10, 4))
sns.barplot(data=df, x='brand_name', y='internal_memory', palette='Set1')
plt.xlabel('Brand Name')
plt.ylabel('Internal Memory')
plt.title('Brand Name vs Internal Memory')
plt.xticks(rotation=90, ha='right')
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.barplot(data=sorted_df,x='num_cores',y='processor_speed',palette='Accent')
plt.title('Cores vs Speed')
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.barplot(data=sorted_df,x='os',y='processor_speed',palette='CMRmap')
plt.title('OS vs Processor speed')
plt.show()
